# %%
"""
Solving FrozenLake8x8 environment using Policy iteration.
Author : Moustafa Alzantot (malzantot@ucla.edu)
"""
import numpy as np
import gym
from gym import wrappers


def run_episode(env, policy, gamma = 1.0, render = False):
    """ Runs an episode and return the total reward """
    obs = env.reset()
    total_reward = 0
    step_idx = 0
    while True:
        if render:
            env.render()
        obs, reward, done , _ = env.step(int(policy[obs]))
        total_reward += (gamma ** step_idx * reward)
        step_idx += 1
        if done:
            break
    return total_reward

# %%
def evaluate_policy(env, policy, gamma = 1.0, n = 100):
    scores = [run_episode(env, policy, gamma, False) for _ in range(n)]
    return np.mean(scores)

# %%
def extract_policy(v, gamma = 1.0):
    """ Extract the policy given a value-function """
    policy = np.zeros(env.nS)
    for s in range(env.nS):
        q_sa = np.zeros(env.nA)
        for a in range(env.nA):
            q_sa[a] = sum([p * (r + gamma * v[s_]) for p, s_, r, _ in  env.P[s][a]])
        policy[s] = np.argmax(q_sa)   #贪婪式的提高方法
    return policy

# %%
def compute_policy_v(env, policy, gamma=1.0):
    """ Iteratively evaluate the value-function under policy.
    Alternatively, we could formulate a set of linear equations in iterms of v[s] 
    and solve them to find the value function.
    """
    v = np.zeros(env.nS)
    eps = 1e-10
    while True:
        prev_v = np.copy(v)
        for s in range(env.nS):
            policy_a = policy[s]
            v[s] = sum([p * (r + gamma * prev_v[s_]) for p, s_, r, _ in env.P[s][policy_a]])
        if (np.sum((np.fabs(prev_v - v))) <= eps):
            # value converged
            break
    return v

# %%
def policy_iteration(env, gamma = 1.0):
    """ Policy-Iteration algorithm """
    policy = np.random.choice(env.nA, size=(env.nS))  # initialize a random policy
    max_iterations = 200000
    gamma = 1.0
    for i in range(max_iterations):
        old_policy_v = compute_policy_v(env, policy, gamma)
        new_policy = extract_policy(old_policy_v, gamma)
        if (np.all(policy == new_policy)):
            print ('Policy-Iteration converged at step %d.' %(i+1))
            break
        policy = new_policy
    return policy

# %%
if __name__ == '__main__':
    env_name  = 'FrozenLake8x8-v0'
    env = gym.make(env_name)
    optimal_policy = policy_iteration(env, gamma = 1.0)
    scores = evaluate_policy(env, optimal_policy, gamma = 1.0)
    print('Average scores = ', np.mean(scores))
# Out:
# Policy-Iteration converged at step 12.
# Average scores =  0.9

# %%
import tensorflow as tf
import numpy as np
import random
import gym
import math
import matplotlib.pyplot as plt

def softmax(x):
    e_x = np.exp(x - np.max(x))
    out = e_x / e_x.sum()
    return out


def policy_value():
    with tf.variable_scope("policy_value"):
        state = tf.placeholder("float",[None,4])

        #newvals is future reward
        newvals = tf.placeholder("float",[None,1])

        w1 = tf.get_variable("w1",[4,10])
        b1 = tf.get_variable("b1",[10])

        h1 = tf.nn.relu(tf.matmul(state,w1) + b1)
        w2 = tf.get_variable("w2",[10,2])
        b2 = tf.get_variable("b2",[2])

        w3 = tf.get_variable("w3",[10,1])
        b3 = tf.get_variable("b3",[1])

        #policy gradient
        calculated = tf.matmul(h1,w2) + b2
        probabilities = tf.nn.softmax(calculated)

        actions = tf.placeholder("float",[None,2])
        advantages = tf.placeholder("float",[None,1])

        good_probabilities = tf.reduce_sum(tf.multiply(probabilities, actions),reduction_indices=[1])
        eligibility = tf.log(good_probabilities) * advantages
        loss1 = -tf.reduce_sum(eligibility)

        #value gradient
        calculated1 = tf.matmul(h1,w3) + b3
        diffs = calculated1 - newvals
        loss2 = tf.nn.l2_loss(diffs)

        #policy loss + value loss
        loss = loss1+loss2

        optimizer = tf.train.AdamOptimizer(0.01).minimize(loss)#AdamOptimizer

        return probabilities,calculated1, actions,state,advantages, newvals, optimizer, loss1,loss2

def run_episode(env, policy_value, sess,is_train = True):    
    p_probabilities,v_calculated,p_actions, pv_state, p_advantages, v_newvals, pv_optimizer,loss1,loss2 = policy_value

    observation = env.reset()
    totalreward = 0
    states = []
    actions = []
    advantages = []
    transitions = []
    update_vals = []


    for _ in range(200):
        # calculate policy
        obs_vector = np.expand_dims(observation, axis=0)
        #calculate action according to current state
        probs = sess.run(p_probabilities,feed_dict={pv_state: obs_vector})

        action = 1 if probs[0][0]<probs[0][1] else 0
        #take a random action when training
        if is_train:
            action = 0 if random.uniform(0,1) < probs[0][0] else 1
        # record the transition
        states.append(observation)
        actionblank = np.zeros(2)
        actionblank[action] = 1
        actions.append(actionblank)
        # take the action in the environment
        old_observation = observation
        observation, reward, done, info = env.step(action)
        transitions.append((old_observation, action, reward))
        totalreward += reward

        if done:
            break
    #return totalreward if it is testing
    if not is_train:
        return totalreward

    #training
    for index, trans in enumerate(transitions):
        obs, action, reward = trans

        # calculate discounted monte-carlo return
        future_reward = 0
        future_transitions = len(transitions) - index
        decrease = 1
        for index2 in range(future_transitions):
            future_reward += transitions[(index2) + index][2] * decrease
            decrease = decrease * 0.97
        obs_vector = np.expand_dims(obs, axis=0)
        #value function: calculate max reward under current state 
        currentval = sess.run(v_calculated,feed_dict={pv_state: obs_vector})[0][0]

        # advantage: how much better was this action than normal
        # 根据实际数据得到future_reward比值函数计算出来的reward要好多少
        # 训练到后来,这个currentval:即在当前reward会估计的比较准确,在当前state下能够获得的
        # 最大reward或者平均reward,而有了这个估计,用实际的reward减去这个reward,就可以判断这个
        # action的好坏,即这个currentval是训练时用来评估某个action的好坏
        # 用future_reward减去这个最大reward,就得到了这个action
        # 对应的label,如果比估计的值更大,那说明要根据该参数进行更新,如果比该值小,那说明
        # 达不到平均水平,那么将将该action对应的梯度进行反向更新(相减为负值),使得下次碰到这个
        # 类似的state的时候,不再采取这个action
        advantages.append(future_reward - currentval)

        #advantages.append(future_reward-2.0)

        update_vals.append(future_reward)

    # update value function
    update_vals_vector = np.expand_dims(update_vals, axis=1)

    advantages_vector = np.expand_dims(advantages, axis=1)
    #train network
    _,print_loss1,print_loss2 = sess.run([pv_optimizer,loss1,loss2], feed_dict={pv_state: states,v_newvals: update_vals_vector, p_advantages: advantages_vector, p_actions: actions})

    print("policy loss ",print_loss1)
    print("value loss ",print_loss2)
    return totalreward


env = gym.make('CartPole-v0')

PolicyValue = policy_value()

sess = tf.InteractiveSession()

sess.run(tf.global_variables_initializer())

for i in range(1500):
    reward = run_episode(env, PolicyValue, sess)

t = 0
for _ in range(1000):
    #env.render()
    reward = run_episode(env, PolicyValue, sess,False)
    t += reward
print(t / 1000)
# Out:
# WARNING:tensorflow:From D:\Anacaonda\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Anacaonda\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# policy loss  455.7054
# value loss  239.71481
# policy loss  729.7158
# value loss  364.66998
# policy loss  423.19095
# value loss  239.75842
# policy loss  536.0046
# value loss  296.5809
# policy loss  2068.702
# value loss  909.6444
# policy loss  228.42177
# value loss  141.64803
# policy loss  1276.2365
# value loss  591.4498
# policy loss  406.60703
# value loss  231.26395
# policy loss  4734.3013
# value loss  1761.7063
# policy loss  52711.68
# value loss  13684.197
# policy loss  2488.8054
# value loss  1017.84656
# policy loss  36231.516
# value loss  9388.404
# policy loss  4091.1638
# value loss  1567.7795
# policy loss  2563.1375
# value loss  989.8098
# policy loss  655.36816
# value loss  338.60156
# policy loss  1055.596
# value loss  484.67856
# policy loss  1422.6884
# value loss  659.66394
# policy loss  1693.0361
# value loss  758.8818
# policy loss  13520.119
# value loss  4215.286
# policy loss  2908.982
# value loss  1245.8408
# policy loss  1918.3585
# value loss  869.6219
# policy loss  6237.008
# value loss  2406.7551
# policy loss  58728.47
# value loss  14706.587
# policy loss  3162.1787
# value loss  1223.3372
# policy loss  2434.2002
# value loss  958.4967
# policy loss  2047.5334
# value loss  740.0693
# policy loss  1361.5918
# value loss  638.36237
# policy loss  16144.899
# value loss  5284.6636
# policy loss  37674.72
# value loss  10582.154
# policy loss  6040.903
# value loss  2368.6958
# policy loss  3353.6604
# value loss  1348.1199
# policy loss  7066.2173
# value loss  2538.007
# policy loss  4250.108
# value loss  1637.3466
# policy loss  1144.6608
# value loss  529.421
# policy loss  3175.8916
# value loss  1325.6768
# policy loss  8579.13
# value loss  3172.84
# policy loss  27007.926
# value loss  7919.4688
# policy loss  4265.9214
# value loss  1611.2682
# policy loss  2901.4663
# value loss  1166.0095
# policy loss  156997.12
# value loss  30554.736
# policy loss  2793.5457
# value loss  1159.9677
# policy loss  3950.7017
# value loss  1583.0417
# policy loss  4500.857
# value loss  1538.9548
# policy loss  1390.7314
# value loss  585.0501
# policy loss  69933.01
# value loss  17089.44
# policy loss  27306.34
# value loss  8467.515
# policy loss  22218.998
# value loss  6485.8574
# policy loss  3038.6892
# value loss  1098.0845
# policy loss  31123.113
# value loss  9052.034
# policy loss  295765.7
# value loss  46652.69
# policy loss  1792.2843
# value loss  746.22955
# policy loss  29960.922
# value loss  9034.9795
# policy loss  51225.766
# value loss  13007.954
# policy loss  5746.164
# value loss  2176.626
# policy loss  37325.023
# value loss  10709.033
# policy loss  26502.922
# value loss  8239.735
# policy loss  3199.358
# value loss  1188.1757
# policy loss  5047.072
# value loss  1765.4696
# policy loss  5758.0737
# value loss  2121.6646
# policy loss  52549.91
# value loss  12822.022
# policy loss  23298.146
# value loss  7156.6064
# policy loss  10714.785
# value loss  3542.4783
# policy loss  1743.853
# value loss  694.6996
# policy loss  53815.695
# value loss  13384.932
# policy loss  16382.642
# value loss  5015.807
# policy loss  4561.3647
# value loss  1548.5569
# policy loss  15182.77
# value loss  4659.331
# policy loss  13155.285
# value loss  4382.583
# policy loss  26229.27
# value loss  7631.6504
# policy loss  72072.24
# value loss  17429.033
# policy loss  3483.164
# value loss  1385.726
# policy loss  7684.401
# value loss  2587.1995
# policy loss  58087.94
# value loss  13992.3125
# policy loss  67909.83
# value loss  16868.602
# policy loss  3345.9065
# value loss  1212.0704
# policy loss  55410.03
# value loss  13905.354
# policy loss  27615.996
# value loss  8073.1206
# policy loss  56834.625
# value loss  13800.293
# policy loss  41270.1
# value loss  10930.405
# policy loss  16539.086
# value loss  5306.4575
# policy loss  2572.035
# value loss  805.5171
# policy loss  37622.113
# value loss  10265.36
# policy loss  24070.664
# value loss  7235.571
# policy loss  3406.525
# value loss  1168.5571
# policy loss  3946.7146
# value loss  1285.8112
# policy loss  3180.8496
# value loss  1128.2637
# policy loss  25347.863
# value loss  7414.4097
# policy loss  5141.8823
# value loss  1854.8284
# policy loss  6173.3774
# value loss  1961.9023
# policy loss  8885.699
# value loss  2972.32
# policy loss  100052.72
# value loss  21207.43
# policy loss  908.8814
# value loss  351.81915
# policy loss  2358.1963
# value loss  860.4483
# policy loss  1681.5497
# value loss  649.3929
# policy loss  9818.736
# value loss  3345.0
# policy loss  8828.372
# value loss  3120.424
# policy loss  16502.73
# value loss  5230.442
# policy loss  99805.01
# value loss  20991.574
# policy loss  8322.645
# value loss  2846.1592
# policy loss  79085.0
# value loss  18046.035
# policy loss  23998.67
# value loss  7127.8804
# policy loss  8169.987
# value loss  2838.3867
# policy loss  17446.982
# value loss  5334.9326
# policy loss  5720.9277
# value loss  1784.2344
# policy loss  2691.467
# value loss  1045.5303
# policy loss  22400.121
# value loss  6698.6655
# policy loss  26922.531
# value loss  7901.4434
# policy loss  3860.4917
# value loss  1397.8467
# policy loss  58354.297
# value loss  14786.285
# policy loss  111185.7
# value loss  22746.154
# policy loss  109749.25
# value loss  23223.162
# policy loss  57630.02
# value loss  13730.477
# policy loss  38333.95
# value loss  10127.531
# policy loss  21127.43
# value loss  6085.517
# policy loss  239532.03
# value loss  39488.016
# policy loss  279807.16
# value loss  43330.605
# policy loss  93821.86
# value loss  20290.111
# policy loss  128732.8
# value loss  25340.102
# policy loss  41100.188
# value loss  10701.111
# policy loss  76183.91
# value loss  17408.293
# policy loss  43946.734
# value loss  11216.211
# policy loss  74487.27
# value loss  16322.766
# policy loss  15525.014
# value loss  4848.005
# policy loss  15117.135
# value loss  4832.1113
# policy loss  28137.992
# value loss  8085.131
# policy loss  47782.88
# value loss  11407.217
# policy loss  7330.729
# value loss  2379.8276
# policy loss  77939.93
# value loss  17598.334
# policy loss  38116.61
# value loss  9443.145
# policy loss  108675.23
# value loss  21711.242
# policy loss  2972.3452
# value loss  1027.1841
# policy loss  63710.492
# value loss  13400.575
# policy loss  165703.06
# value loss  28575.807
# policy loss  29294.564
# value loss  8052.6255
# policy loss  91219.38
# value loss  20131.73
# policy loss  15268.529
# value loss  4769.0723
# policy loss  114033.89
# value loss  22534.902
# policy loss  65404.445
# value loss  14561.333
# policy loss  61415.895
# value loss  13006.6
# policy loss  24320.578
# value loss  6460.9893
# policy loss  85336.03
# value loss  16960.994
# policy loss  179129.3
# value loss  29506.38
# policy loss  55914.348
# value loss  12220.849
# policy loss  7029.5435
# value loss  2041.7152
# policy loss  88439.97
# value loss  18221.234
# policy loss  47825.84
# value loss  11456.113
# policy loss  45880.96
# value loss  11009.058
# policy loss  227383.84
# value loss  34607.305
# policy loss  148091.05
# value loss  25177.564
# policy loss  32756.066
# value loss  8783.083
# policy loss  49070.305
# value loss  11607.937
# policy loss  237811.3
# value loss  35611.715
# policy loss  41076.246
# value loss  9753.92
# policy loss  60155.098
# value loss  12103.693
# policy loss  482710.03
# value loss  53448.227
# policy loss  7407.2197
# value loss  2309.3276
# policy loss  29656.457
# value loss  6444.7207
# policy loss  152057.39
# value loss  25556.496
# policy loss  165533.58
# value loss  26493.816
# policy loss  55219.03
# value loss  12192.572
# policy loss  92939.81
# value loss  16811.463
# policy loss  18888.342
# value loss  5048.8916
# policy loss  81200.39
# value loss  15397.304
# policy loss  18772.3
# value loss  5348.8247
# policy loss  9706.596
# value loss  2827.814
# policy loss  77605.5
# value loss  14070.455
# policy loss  334914.5
# value loss  37132.28
# policy loss  130336.2
# value loss  20256.037
# policy loss  124771.06
# value loss  20326.086
# policy loss  187587.36
# value loss  23992.043
# policy loss  304194.25
# value loss  35971.19
# policy loss  248418.73
# value loss  31272.057
# policy loss  289327.4
# value loss  35284.793
# policy loss  144700.61
# value loss  21486.348
# policy loss  378702.44
# value loss  34443.016
# policy loss  245426.84
# value loss  29143.457
# policy loss  288994.62
# value loss  31279.285
# policy loss  319284.56
# value loss  33004.57
# policy loss  126710.2
# value loss  18089.889
# policy loss  35190.6
# value loss  6679.211
# policy loss  140048.36
# value loss  19387.969
# policy loss  416833.7
# value loss  38538.773
# policy loss  142559.1
# value loss  18380.648
# policy loss  201327.6
# value loss  23562.303
# policy loss  433.1053
# value loss  426.97437
# policy loss  167553.9
# value loss  20323.54
# policy loss  70951.26
# value loss  10862.06
# policy loss  221483.72
# value loss  23020.922
# policy loss  931.21985
# value loss  649.1178
# policy loss  315.0408
# value loss  804.76556
# policy loss  98940.57
# value loss  13229.162
# policy loss  412985.75
# value loss  35873.973
# policy loss  178004.88
# value loss  20362.121
# policy loss  -1550.1754
# value loss  521.87854
# policy loss  361983.88
# value loss  32894.97
# policy loss  673.65497
# value loss  899.24316
# policy loss  173149.36
# value loss  18181.941
# policy loss  369503.3
# value loss  29668.703
# policy loss  352637.06
# value loss  27459.684
# policy loss  29617.223
# value loss  4649.4155
# policy loss  344337.34
# value loss  27062.018
# policy loss  147794.88
# value loss  15738.625
# policy loss  344240.8
# value loss  25238.127
# policy loss  309946.06
# value loss  23884.799
# policy loss  114199.03
# value loss  11868.88
# policy loss  -1277.5114
# value loss  1091.6562
# policy loss  296607.84
# value loss  22195.51
# policy loss  219500.47
# value loss  17803.873
# policy loss  154929.47
# value loss  13965.289
# policy loss  169711.12
# value loss  15152.905
# policy loss  18094.129
# value loss  4028.141
# policy loss  75154.21
# value loss  8479.187
# policy loss  41940.938
# value loss  6270.742
# policy loss  24661.707
# value loss  4586.814
# policy loss  -2831.5227
# value loss  1060.0364
# policy loss  35214.016
# value loss  5962.227
# policy loss  -2746.627
# value loss  1589.6942
# policy loss  -3858.8057
# value loss  1084.0908
# policy loss  -3594.8337
# value loss  1278.6556
# policy loss  25141.46
# value loss  5298.245
# policy loss  -2452.6226
# value loss  1284.2478
# policy loss  -2528.536
# value loss  1608.6848
# policy loss  -2750.2783
# value loss  1487.5938
# policy loss  -3202.4558
# value loss  2022.5295
# policy loss  -2049.9077
# value loss  2242.9312
# policy loss  -3997.5737
# value loss  1344.5431
# policy loss  -2625.4868
# value loss  1744.6798
# policy loss  -3729.968
# value loss  1275.9377
# policy loss  -2699.255
# value loss  1613.3734
# policy loss  -2360.3423
# value loss  1442.365
# policy loss  -2619.7898
# value loss  1351.8469
# policy loss  -5015.415
# value loss  1358.5602
# policy loss  -2258.4849
# value loss  1431.0901
# policy loss  -4295.315
# value loss  1351.5151
# policy loss  -4843.6016
# value loss  1346.2391
# policy loss  10978.834
# value loss  4504.4355
# policy loss  -1723.8795
# value loss  1526.9382
# policy loss  -3281.9006
# value loss  1389.6295
# policy loss  -3711.4792
# value loss  1393.7578
# policy loss  -3826.245
# value loss  1215.8976
# policy loss  -2661.388
# value loss  1554.0736
# policy loss  -3544.2998
# value loss  1341.1565
# policy loss  -3550.703
# value loss  1534.651
# policy loss  -2020.6508
# value loss  1314.971
# policy loss  -2727.002
# value loss  1507.2368
# policy loss  -3775.247
# value loss  1166.9019
# policy loss  -1758.7421
# value loss  1317.804
# policy loss  -3343.3384
# value loss  1118.1604
# policy loss  -2028.4874
# value loss  1462.6348
# policy loss  -2261.4087
# value loss  1234.7712
# policy loss  -1997.3124
# value loss  1143.2649
# policy loss  -3493.7407
# value loss  1132.022
# policy loss  8580.6455
# value loss  4380.2114
# policy loss  -2971.5825
# value loss  1232.3026
# policy loss  -2449.9856
# value loss  1233.0504
# policy loss  -1308.0757
# value loss  1169.688
# policy loss  -2261.3127
# value loss  1060.2424
# policy loss  -3259.857
# value loss  1081.987
# policy loss  -3087.0654
# value loss  1089.0498
# policy loss  -3530.9917
# value loss  1067.7375
# policy loss  -2338.2114
# value loss  1021.41284
# policy loss  -2086.5928
# value loss  1029.6727
# policy loss  -2440.8613
# value loss  991.1724
# policy loss  -3097.3035
# value loss  966.4461
# policy loss  11985.334
# value loss  3984.509
# policy loss  -2133.189
# value loss  1115.3236
# policy loss  -2210.2131
# value loss  944.97845
# policy loss  1735.0645
# value loss  1895.8013
# policy loss  -2499.5913
# value loss  969.0131
# policy loss  -3421.4932
# value loss  1242.2367
# policy loss  -2597.7942
# value loss  903.8262
# policy loss  -2396.7266
# value loss  928.5218
# policy loss  -2694.2656
# value loss  1051.2758
# policy loss  -2675.616
# value loss  911.4593
# policy loss  -2650.019
# value loss  979.4734
# policy loss  -2265.4033
# value loss  998.73975
# policy loss  -1938.5845
# value loss  878.1521
# policy loss  -2809.9614
# value loss  970.13055
# policy loss  -2264.9822
# value loss  901.0768
# policy loss  -3191.0847
# value loss  962.1267
# policy loss  -2253.7256
# value loss  1075.9302
# policy loss  -2717.4644
# value loss  991.6522
# policy loss  -2059.449
# value loss  1203.5343
# policy loss  -1944.5326
# value loss  894.2306
# policy loss  -2466.3887
# value loss  823.2696
# policy loss  -1388.4353
# value loss  1053.0146
# policy loss  -2696.0947
# value loss  788.1045
# policy loss  20108.799
# value loss  5496.423
# policy loss  -2423.2134
# value loss  757.9035
# policy loss  -2400.0342
# value loss  799.31085
# policy loss  9124.76
# value loss  3625.6084
# policy loss  -2447.001
# value loss  792.227
# policy loss  -1813.0312
# value loss  1125.8014
# policy loss  3006.039
# value loss  1645.6252
# policy loss  16068.319
# value loss  4910.2007
# policy loss  -2151.5884
# value loss  829.9442
# policy loss  1409.7817
# value loss  1932.8402
# policy loss  -1745.2954
# value loss  834.4262
# policy loss  -2336.8726
# value loss  780.2545
# policy loss  588.33014
# value loss  1290.5802
# policy loss  52260.688
# value loss  8079.427
# policy loss  -2371.925
# value loss  827.0517
# policy loss  -1939.647
# value loss  713.304
# policy loss  -1665.9163
# value loss  929.4158
# policy loss  -2571.8274
# value loss  802.3062
# policy loss  -1845.637
# value loss  726.44507
# policy loss  -2256.1265
# value loss  720.6312
# policy loss  42245.52
# value loss  7047.8877
# policy loss  5103.0967
# value loss  2185.1743
# policy loss  22316.93
# value loss  4917.2695
# policy loss  -2670.8157
# value loss  762.4573
# policy loss  57001.406
# value loss  7744.953
# policy loss  59751.67
# value loss  7245.195
# policy loss  3133.163
# value loss  1869.9984
# policy loss  32174.379
# value loss  6555.0835
# policy loss  -1928.583
# value loss  885.62854
# policy loss  55560.523
# value loss  7811.2915
# policy loss  99087.875
# value loss  9767.351
# policy loss  51753.46
# value loss  7698.5913
# policy loss  90176.016
# value loss  10043.12
# policy loss  87803.95
# value loss  10110.412
# policy loss  122048.04
# value loss  12098.537
# policy loss  124532.6
# value loss  11853.162
# policy loss  116686.17
# value loss  10877.6875
# policy loss  137122.31
# value loss  11601.851
# policy loss  196842.98
# value loss  14731.414
# policy loss  213801.81
# value loss  15090.927
# policy loss  90901.08
# value loss  8968.937
# policy loss  161544.56
# value loss  12594.901
# policy loss  202099.4
# value loss  14146.26
# policy loss  173184.33
# value loss  12772.956
# policy loss  100684.79
# value loss  9828.184
# policy loss  184769.84
# value loss  12968.92
# policy loss  128979.62
# value loss  11006.456
# policy loss  169853.05
# value loss  11874.964
# policy loss  108446.58
# value loss  9168.299
# policy loss  160183.81
# value loss  11692.728
# policy loss  87218.586
# value loss  8251.266
# policy loss  133841.23
# value loss  10041.623
# policy loss  141148.4
# value loss  9441.807
# policy loss  123383.14
# value loss  9836.702
# policy loss  76978.5
# value loss  7359.374
# policy loss  98561.17
# value loss  7813.9575
# policy loss  78342.03
# value loss  7981.8096
# policy loss  117160.47
# value loss  8509.786
# policy loss  53242.223
# value loss  6372.567
# policy loss  46389.93
# value loss  5738.996
# policy loss  10004.129
# value loss  4612.912
# policy loss  53051.35
# value loss  5939.494
# policy loss  28267.637
# value loss  5374.3994
# policy loss  40582.484
# value loss  5169.3877
# policy loss  21869.236
# value loss  4356.104
# policy loss  45793.9
# value loss  5282.5664
# policy loss  5527.149
# value loss  3498.665
# policy loss  52816.203
# value loss  5058.385
# policy loss  50157.688
# value loss  4885.3525
# policy loss  46819.547
# value loss  4536.5225
# policy loss  49937.695
# value loss  4569.6055
# policy loss  20941.596
# value loss  3668.1465
# policy loss  61552.797
# value loss  5059.647
# policy loss  63914.797
# value loss  4446.4336
# policy loss  34402.293
# value loss  3430.6406
# policy loss  38616.758
# value loss  3574.8936
# policy loss  39750.234
# value loss  3445.272
# policy loss  60547.88
# value loss  4230.996
# policy loss  42015.953
# value loss  3282.9978
# policy loss  47577.875
# value loss  3029.491
# policy loss  31305.172
# value loss  2921.6365
# policy loss  45486.438
# value loss  4022.7593
# policy loss  75002.336
# value loss  3514.142
# policy loss  60548.766
# value loss  3264.9358
# policy loss  9897.929
# value loss  4505.791
# policy loss  80043.42
# value loss  3474.5352
# policy loss  77281.36
# value loss  3473.1765
# policy loss  -13447.509
# value loss  4835.0103
# policy loss  34398.457
# value loss  3400.121
# policy loss  8524.377
# value loss  3683.1455
# policy loss  63753.734
# value loss  3100.051
# policy loss  32217.354
# value loss  3376.3804
# policy loss  45912.008
# value loss  3143.0178
# policy loss  34284.28
# value loss  2552.0852
# policy loss  48697.2
# value loss  2015.6523
# policy loss  62889.43
# value loss  3772.4846
# policy loss  39825.48
# value loss  1646.3269
# policy loss  54127.117
# value loss  2147.136
# policy loss  30756.762
# value loss  1741.6333
# policy loss  38161.203
# value loss  2067.1523
# policy loss  28528.0
# value loss  1357.7463
# policy loss  11554.867
# value loss  1214.5068
# policy loss  34718.9
# value loss  1982.9049
# policy loss  18299.9
# value loss  1489.27
# policy loss  14703.625
# value loss  1326.5021
# policy loss  -10319.938
# value loss  6320.6875
# policy loss  -19912.922
# value loss  6454.978
# policy loss  3215.379
# value loss  1193.9341
# policy loss  -9631.536
# value loss  6461.3477
# policy loss  629.11523
# value loss  1316.4945
# policy loss  700.3013
# value loss  1102.2546
# policy loss  -244.2666
# value loss  967.9663
# policy loss  -2192.251
# value loss  836.1979
# policy loss  -10889.807
# value loss  812.12476
# policy loss  16997.758
# value loss  1037.3121
# policy loss  -38800.586
# value loss  5777.9707
# policy loss  16298.02
# value loss  766.1823
# policy loss  20652.297
# value loss  1074.3423
# policy loss  11020.543
# value loss  1035.6498
# policy loss  1066.5944
# value loss  485.2607
# policy loss  17709.967
# value loss  666.2361
# policy loss  17740.752
# value loss  908.77734
# policy loss  11576.377
# value loss  742.918
# policy loss  14834.487
# value loss  628.3285
# policy loss  35017.406
# value loss  1270.4213
# policy loss  25494.613
# value loss  550.4645
# policy loss  42408.977
# value loss  1776.3522
# policy loss  9299.788
# value loss  720.00934
# policy loss  27871.98
# value loss  816.7132
# policy loss  22600.463
# value loss  604.3433
# policy loss  33921.703
# value loss  990.55505
# policy loss  14517.307
# value loss  746.3108
# policy loss  6507.1094
# value loss  480.76553
# policy loss  12094.508
# value loss  652.7211
# policy loss  10142.1045
# value loss  554.62695
# policy loss  -59338.77
# value loss  3168.6816
# policy loss  32964.85
# value loss  1461.882
# policy loss  -21474.78
# value loss  1797.0592
# policy loss  3593.685
# value loss  679.3834
# policy loss  20778.553
# value loss  727.929
# policy loss  -9854.275
# value loss  690.6182
# policy loss  15517.726
# value loss  536.1797
# policy loss  32105.902
# value loss  1176.5859
# policy loss  -246.0924
# value loss  441.2422
# policy loss  -5356.6606
# value loss  379.78726
# policy loss  -567.9573
# value loss  314.65225
# policy loss  -2111.481
# value loss  336.51816
# policy loss  -8010.086
# value loss  364.83197
# policy loss  -1165.8604
# value loss  379.78577
# policy loss  18816.316
# value loss  801.308
# policy loss  21948.875
# value loss  1057.3755
# policy loss  5877.9785
# value loss  484.2671
# policy loss  20758.553
# value loss  1048.5404
# policy loss  936.9907
# value loss  274.83652
# policy loss  13319.882
# value loss  565.243
# policy loss  5317.2534
# value loss  411.3175
# policy loss  11090.387
# value loss  659.69104
# policy loss  15583.682
# value loss  743.29425
# policy loss  -5285.442
# value loss  402.93726
# policy loss  15647.306
# value loss  999.84
# policy loss  24466.043
# value loss  998.55963
# policy loss  16295.644
# value loss  940.65173
# policy loss  21268.797
# value loss  1189.4005
# policy loss  -18408.895
# value loss  557.41455
# policy loss  -23430.963
# value loss  548.65576
# policy loss  10147.635
# value loss  870.82446
# policy loss  -12864.884
# value loss  501.9493
# policy loss  27084.674
# value loss  1441.8561
# policy loss  2672.5493
# value loss  775.24304
# policy loss  27837.684
# value loss  1175.0894
# policy loss  11320.905
# value loss  852.91943
# policy loss  -5804.839
# value loss  593.58856
# policy loss  16556.547
# value loss  1108.0052
# policy loss  -48353.992
# value loss  2122.7734
# policy loss  3261.4873
# value loss  627.95276
# policy loss  5655.404
# value loss  2109.3486
# policy loss  -44029.227
# value loss  2125.2432
# policy loss  16318.649
# value loss  1697.1283
# policy loss  24001.803
# value loss  2397.3176
# policy loss  11885.326
# value loss  659.9741
# policy loss  8880.645
# value loss  683.5105
# policy loss  34423.586
# value loss  1785.7935
# policy loss  16397.135
# value loss  1161.9519
# policy loss  46061.195
# value loss  2251.0547
# policy loss  43209.383
# value loss  1925.6652
# policy loss  52722.766
# value loss  2280.058
# policy loss  11409.689
# value loss  915.91943
# policy loss  13597.824
# value loss  1559.6708
# policy loss  19931.82
# value loss  1507.1917
# policy loss  22313.04
# value loss  1460.5144
# policy loss  6050.828
# value loss  1121.362
# policy loss  -8718.181
# value loss  1218.844
# policy loss  -10073.072
# value loss  670.6763
# policy loss  -6265.662
# value loss  1114.6448
# policy loss  -7769.9604
# value loss  1080.4785
# policy loss  -21878.21
# value loss  818.2039
# policy loss  1291.2861
# value loss  1293.1633
# policy loss  10853.406
# value loss  2075.1782
# policy loss  31276.928
# value loss  2378.579
# policy loss  -8844.801
# value loss  1139.0468
# policy loss  -72728.2
# value loss  3560.2886
# policy loss  12216.192
# value loss  1856.4347
# policy loss  6438.051
# value loss  2081.69
# policy loss  -14139.854
# value loss  1917.4734
# policy loss  9798.527
# value loss  1862.1456
# policy loss  15088.055
# value loss  1758.4613
# policy loss  11781.11
# value loss  1783.9172
# policy loss  -22358.035
# value loss  8701.179
# policy loss  -23354.488
# value loss  1112.9401
# policy loss  32126.865
# value loss  2524.0376
# policy loss  -6187.826
# value loss  2640.2488
# policy loss  -28350.941
# value loss  1149.4578
# policy loss  2907.6384
# value loss  1374.0859
# policy loss  -22506.605
# value loss  1533.175
# policy loss  -49890.938
# value loss  4209.8115
# policy loss  -31304.193
# value loss  1181.9105
# policy loss  11460.599
# value loss  1400.153
# policy loss  64822.914
# value loss  4326.959
# policy loss  33466.746
# value loss  2598.2214
# policy loss  -1163.0039
# value loss  1109.829
# policy loss  37339.45
# value loss  2291.7417
# policy loss  68233.55
# value loss  3825.4165
# policy loss  52087.9
# value loss  3997.043
# policy loss  -15309.709
# value loss  1091.55
# policy loss  -53996.59
# value loss  6860.5693
# policy loss  -52385.266
# value loss  5540.5986
# policy loss  -47638.863
# value loss  6333.9634
# policy loss  -54954.79
# value loss  3555.9023
# policy loss  23845.2
# value loss  3237.7603
# policy loss  -44460.43
# value loss  4121.052
# policy loss  -52607.586
# value loss  4318.7026
# policy loss  22881.422
# value loss  2507.4004
# policy loss  48472.977
# value loss  3274.9211
# policy loss  -34683.152
# value loss  2123.2053
# policy loss  23677.795
# value loss  2530.1646
# policy loss  10203.754
# value loss  1633.7563
# policy loss  52487.766
# value loss  6368.41
# policy loss  51080.1
# value loss  3949.5835
# policy loss  48198.574
# value loss  1719.7661
# policy loss  81316.61
# value loss  4150.2607
# policy loss  39858.117
# value loss  2582.4429
# policy loss  45558.54
# value loss  3807.1858
# policy loss  -38014.83
# value loss  2903.7446
# policy loss  5333.9097
# value loss  1024.8883
# policy loss  49902.562
# value loss  2270.688
# policy loss  31078.137
# value loss  1893.3533
# policy loss  -11058.613
# value loss  2055.4695
# policy loss  13564.229
# value loss  1085.8939
# policy loss  35194.332
# value loss  2161.0127
# policy loss  6291.798
# value loss  1073.7421
# policy loss  4869.2554
# value loss  1290.2468
# policy loss  8109.9907
# value loss  1895.8911
# policy loss  31443.492
# value loss  1913.57
# policy loss  -18590.613
# value loss  1156.7784
# policy loss  -27283.8
# value loss  1311.5769
# policy loss  -24611.934
# value loss  1528.8475
# policy loss  -38337.07
# value loss  5538.09
# policy loss  -11838.429
# value loss  1216.3196
# policy loss  -13591.449
# value loss  1306.9736
# policy loss  -8879.525
# value loss  2050.327
# policy loss  -6604.8438
# value loss  1376.0375
# policy loss  -7190.413
# value loss  6587.9175
# policy loss  10141.177
# value loss  1585.7721
# policy loss  26996.943
# value loss  2225.5627
# policy loss  36455.074
# value loss  1433.0994
# policy loss  3390.3784
# value loss  2239.7664
# policy loss  -1379.7822
# value loss  1497.6858
# policy loss  -36822.83
# value loss  1965.3881
# policy loss  30768.33
# value loss  1665.269
# policy loss  32894.504
# value loss  1943.2958
# policy loss  44932.42
# value loss  2074.442
# policy loss  26053.533
# value loss  2871.0713
# policy loss  31239.0
# value loss  2060.7087
# policy loss  -164.5542
# value loss  2184.4312
# policy loss  -20937.969
# value loss  2126.6472
# policy loss  24438.35
# value loss  1758.4548
# policy loss  38585.03
# value loss  2985.2812
# policy loss  5196.7944
# value loss  2035.6416
# policy loss  37049.09
# value loss  1994.4966
# policy loss  42043.027
# value loss  2564.883
# policy loss  51997.902
# value loss  2594.2007
# policy loss  25140.61
# value loss  1657.2195
# policy loss  -15341.746
# value loss  1771.8834
# policy loss  -74.55713
# value loss  1378.6113
# policy loss  -13526.337
# value loss  7730.0674
# policy loss  -515.17065
# value loss  1417.2278
# policy loss  23427.977
# value loss  1591.3124
# policy loss  -40936.773
# value loss  2937.645
# policy loss  44811.81
# value loss  2652.0566
# policy loss  34995.867
# value loss  1668.6631
# policy loss  -38988.55
# value loss  4775.465
# policy loss  34775.953
# value loss  2598.7856
# policy loss  17898.229
# value loss  2050.5845
# policy loss  -12822.601
# value loss  1137.3984
# policy loss  -245.20459
# value loss  1921.8309
# policy loss  32485.242
# value loss  2231.0542
# policy loss  4835.254
# value loss  1421.604
# policy loss  -1849.3198
# value loss  2260.6353
# policy loss  21009.086
# value loss  2069.1145
# policy loss  -6352.368
# value loss  1674.0039
# policy loss  143.84863
# value loss  1291.0938
# policy loss  -28645.188
# value loss  1727.047
# policy loss  -55871.566
# value loss  2811.3918
# policy loss  -11398.811
# value loss  7799.5605
# policy loss  -10133.08
# value loss  1292.0314
# policy loss  14283.828
# value loss  1936.6165
# policy loss  -5028.351
# value loss  936.49255
# policy loss  -1646.4647
# value loss  1040.8939
# policy loss  4461.857
# value loss  947.20825
# policy loss  7679.4995
# value loss  1369.0535
# policy loss  -12161.126
# value loss  821.3924
# policy loss  28226.166
# value loss  2747.6785
# policy loss  8100.843
# value loss  886.9044
# policy loss  28313.045
# value loss  1729.672
# policy loss  -5142.7856
# value loss  5681.914
# policy loss  -8157.3135
# value loss  1152.2268
# policy loss  -4937.94
# value loss  5676.0483
# policy loss  53526.72
# value loss  2300.2383
# policy loss  26612.29
# value loss  1938.0656
# policy loss  -5491.3364
# value loss  1780.2095
# policy loss  -39255.816
# value loss  8165.2725
# policy loss  23324.13
# value loss  1962.6989
# policy loss  24017.52
# value loss  2405.4883
# policy loss  -9096.504
# value loss  6336.3896
# policy loss  -17379.365
# value loss  1296.1592
# policy loss  16350.285
# value loss  1984.0094
# policy loss  -6570.27
# value loss  2009.8923
# policy loss  -75663.47
# value loss  3292.1147
# policy loss  -22726.908
# value loss  2030.3772
# policy loss  -17725.29
# value loss  2385.5234
# policy loss  -28808.867
# value loss  1963.2815
# policy loss  -38079.83
# value loss  2255.638
# policy loss  -40738.637
# value loss  2679.7178
# policy loss  -24067.244
# value loss  2158.2998
# policy loss  21463.549
# value loss  3416.0405
# policy loss  -29482.945
# value loss  2949.0864
# policy loss  11111.096
# value loss  2637.405
# policy loss  7094.0938
# value loss  1936.7461
# policy loss  58789.176
# value loss  4010.728
# policy loss  20845.533
# value loss  2790.4734
# policy loss  19244.148
# value loss  2358.4463
# policy loss  -9715.217
# value loss  1957.6272
# policy loss  10068.456
# value loss  1518.3468
# policy loss  38959.25
# value loss  2885.8706
# policy loss  85097.414
# value loss  4159.1704
# policy loss  30054.555
# value loss  2315.493
# policy loss  105094.31
# value loss  5445.4517
# policy loss  54153.438
# value loss  2472.231
# policy loss  98477.625
# value loss  4821.9736
# policy loss  110526.03
# value loss  5376.105
# policy loss  73654.45
# value loss  3697.3003
# policy loss  42286.58
# value loss  1950.1492
# policy loss  -40755.656
# value loss  2150.7974
# policy loss  -24128.781
# value loss  1260.6298
# policy loss  -49314.11
# value loss  2303.7483
# policy loss  -37719.05
# value loss  2629.2478
# policy loss  13751.559
# value loss  1222.2627
# policy loss  -26254.193
# value loss  1168.1117
# policy loss  -7340.291
# value loss  782.9275
# policy loss  -6942.951
# value loss  841.54517
# policy loss  -24055.283
# value loss  1183.4022
# policy loss  -8624.37
# value loss  6969.0864
# policy loss  -28839.941
# value loss  1385.4874
# policy loss  16971.615
# value loss  1725.3407
# policy loss  -4900.4004
# value loss  811.4639
# policy loss  14979.68
# value loss  2185.2988
# policy loss  -14047.426
# value loss  7301.6914
# policy loss  -12369.295
# value loss  7279.751
# policy loss  32893.656
# value loss  1959.652
# policy loss  -6935.605
# value loss  6841.222
# policy loss  44859.465
# value loss  1932.0479
# policy loss  19590.633
# value loss  2397.1367
# policy loss  19332.855
# value loss  1631.55
# policy loss  37840.633
# value loss  1927.7924
# policy loss  31542.426
# value loss  1850.6737
# policy loss  11432.634
# value loss  2938.3325
# policy loss  17403.252
# value loss  1559.6919
# policy loss  5972.9634
# value loss  1825.0884
# policy loss  23177.816
# value loss  2677.19
# policy loss  14717.419
# value loss  1878.6866
# policy loss  36140.168
# value loss  2500.5981
# policy loss  7923.615
# value loss  1692.1797
# policy loss  29700.512
# value loss  2607.016
# policy loss  -37614.355
# value loss  2309.6023
# policy loss  39040.613
# value loss  2041.0299
# policy loss  18959.676
# value loss  1941.9529
# policy loss  -8426.376
# value loss  6552.5537
# policy loss  36825.305
# value loss  2231.5857
# policy loss  -7184.582
# value loss  1859.7173
# policy loss  -5805.5923
# value loss  5761.76
# policy loss  -8502.175
# value loss  6324.9346
# policy loss  -8443.053
# value loss  6414.82
# policy loss  -43541.555
# value loss  2573.3777
# policy loss  -44398.137
# value loss  8422.257
# policy loss  10952.223
# value loss  1884.1633
# policy loss  -5966.4507
# value loss  5557.661
# policy loss  -20669.717
# value loss  1594.7568
# policy loss  23620.34
# value loss  1654.3951
# policy loss  11732.869
# value loss  1580.3715
# policy loss  6850.372
# value loss  873.8766
# policy loss  5683.7705
# value loss  1339.2394
# policy loss  -10022.248
# value loss  1109.353
# policy loss  5252.063
# value loss  1988.0366
# policy loss  16192.689
# value loss  1215.5828
# policy loss  7287.975
# value loss  1617.044
# policy loss  34464.453
# value loss  1986.6462
# policy loss  14794.654
# value loss  1992.6172
# policy loss  8991.455
# value loss  1808.3408
# policy loss  32258.094
# value loss  1693.584
# policy loss  33489.49
# value loss  2558.583
# policy loss  38398.28
# value loss  1967.5397
# policy loss  24344.793
# value loss  1882.9684
# policy loss  17652.725
# value loss  1759.7296
# policy loss  25280.844
# value loss  1503.5098
# policy loss  32841.938
# value loss  2224.3323
# policy loss  -5122.3574
# value loss  1497.0369
# policy loss  20427.936
# value loss  2182.0613
# policy loss  32022.389
# value loss  2046.8616
# policy loss  -16845.832
# value loss  1389.0947
# policy loss  -19686.508
# value loss  1167.1877
# policy loss  -7069.99
# value loss  5721.4795
# policy loss  6576.2793
# value loss  1561.6982
# policy loss  -33914.305
# value loss  2420.0112
# policy loss  2949.186
# value loss  1619.1901
# policy loss  -22295.62
# value loss  1632.6953
# policy loss  -5593.754
# value loss  5218.4844
# policy loss  5961.67
# value loss  1783.5054
# policy loss  8487.357
# value loss  1850.7845
# policy loss  -82.96094
# value loss  1647.51
# policy loss  14052.263
# value loss  1871.8301
# policy loss  -14959.393
# value loss  1787.7944
# policy loss  28967.887
# value loss  2368.378
# policy loss  -22286.023
# value loss  1811.2568
# policy loss  5286.4385
# value loss  2214.1147
# policy loss  31497.512
# value loss  2524.4224
# policy loss  -16727.129
# value loss  1608.7612
# policy loss  2788.872
# value loss  1691.9099
# policy loss  9030.069
# value loss  2189.49
# policy loss  -7918.4575
# value loss  1177.177
# policy loss  20919.334
# value loss  2082.039
# policy loss  -12471.467
# value loss  2003.8936
# policy loss  31428.309
# value loss  2272.6655
# policy loss  35409.684
# value loss  3210.69
# policy loss  13344.5625
# value loss  1823.5511
# policy loss  11744.945
# value loss  1549.1967
# policy loss  -6146.5283
# value loss  2077.3801
# policy loss  -10699.274
# value loss  1499.0967
# policy loss  21243.799
# value loss  2931.6526
# policy loss  10757.371
# value loss  2064.2617
# policy loss  -25385.0
# value loss  1316.5962
# policy loss  -14749.094
# value loss  2117.1445
# policy loss  -48371.39
# value loss  5584.539
# policy loss  3596.3262
# value loss  2164.8347
# policy loss  -13807.418
# value loss  2016.255
# policy loss  3721.2876
# value loss  1959.6753
# policy loss  -8117.9375
# value loss  2443.764
# policy loss  -16192.992
# value loss  2679.0762
# policy loss  -10919.714
# value loss  2222.5728
# policy loss  -47999.703
# value loss  2596.1477
# policy loss  -27065.049
# value loss  2359.9646
# policy loss  -15445.928
# value loss  3127.6582
# policy loss  -25363.896
# value loss  2749.9622
# policy loss  -8897.272
# value loss  2806.7214
# policy loss  -63631.58
# value loss  3334.5647
# policy loss  -17790.324
# value loss  2603.7402
# policy loss  -6114.3125
# value loss  2827.519
# policy loss  -2065.1465
# value loss  3231.2627
# policy loss  -11645.03
# value loss  2067.5674
# policy loss  -7591.0264
# value loss  3476.435
# policy loss  6050.799
# value loss  2600.7876
# policy loss  -36120.223
# value loss  3242.3901
# policy loss  39184.754
# value loss  4070.5117
# policy loss  -39951.25
# value loss  4909.0737
# policy loss  -40191.414
# value loss  4115.1245
# policy loss  16882.824
# value loss  3076.0386
# policy loss  23800.447
# value loss  3511.1882
# policy loss  26617.094
# value loss  2828.7998
# policy loss  21597.254
# value loss  2633.7534
# policy loss  63600.746
# value loss  3896.8142
# policy loss  26433.873
# value loss  3083.9995
# policy loss  32699.725
# value loss  3012.897
# policy loss  -46969.195
# value loss  5427.458
# policy loss  39221.77
# value loss  2804.9658
# policy loss  38734.324
# value loss  2577.6763
# policy loss  -43921.535
# value loss  7643.934
# policy loss  50710.87
# value loss  3328.4595
# policy loss  73469.09
# value loss  3671.5276
# policy loss  39440.562
# value loss  2644.4673
# policy loss  -38886.695
# value loss  4627.379
# policy loss  -28393.967
# value loss  2082.2593
# policy loss  52009.797
# value loss  2480.877
# policy loss  83533.83
# value loss  4480.168
# policy loss  89685.08
# value loss  4668.0854
# policy loss  -6367.526
# value loss  5256.684
# policy loss  -30779.105
# value loss  2051.2385
# policy loss  28805.14
# value loss  1667.8538
# policy loss  -32493.805
# value loss  3494.9392
# policy loss  -28632.016
# value loss  2192.9275
# policy loss  35929.0
# value loss  1763.8704
# policy loss  -35365.582
# value loss  3476.0952
# policy loss  20281.275
# value loss  1946.1239
# policy loss  -26916.053
# value loss  2194.0264
# policy loss  29579.344
# value loss  1929.2512
# policy loss  22744.3
# value loss  2547.5312
# policy loss  11193.957
# value loss  2461.4229
# policy loss  536.3965
# value loss  3139.5503
# policy loss  12659.01
# value loss  2465.6982
# policy loss  9735.497
# value loss  2928.3088
# policy loss  -23588.693
# value loss  2750.861
# policy loss  11611.46
# value loss  2761.4775
# policy loss  -61266.37
# value loss  4250.3813
# policy loss  -33522.51
# value loss  2631.6394
# policy loss  -2163.5352
# value loss  2138.7139
# policy loss  -34194.125
# value loss  3012.2217
# policy loss  -16778.75
# value loss  1602.8064
# policy loss  38124.668
# value loss  3159.8252
# policy loss  -30323.287
# value loss  2909.1565
# policy loss  14973.351
# value loss  1760.5704
# policy loss  -13377.936
# value loss  2097.498
# policy loss  15978.663
# value loss  1725.9598
# policy loss  17302.244
# value loss  1709.3167
# policy loss  -12804.436
# value loss  1754.6144
# policy loss  36097.12
# value loss  2259.7441
# policy loss  78183.78
# value loss  3815.2222
# policy loss  35239.492
# value loss  1974.2896
# policy loss  70122.22
# value loss  2994.876
# policy loss  79857.81
# value loss  4379.234
# policy loss  74020.67
# value loss  3510.0374
# policy loss  50768.684
# value loss  2434.0962
# policy loss  -33353.914
# value loss  2726.262
# policy loss  27287.55
# value loss  2225.6582
# policy loss  65549.42
# value loss  3297.8894
# policy loss  -5080.5425
# value loss  2538.9458
# policy loss  33215.586
# value loss  2396.003
# policy loss  29535.945
# value loss  2521.204
# policy loss  32565.918
# value loss  2144.5684
# policy loss  17802.916
# value loss  2009.5146
# policy loss  12422.436
# value loss  2173.883
# policy loss  -54002.58
# value loss  3584.7295
# policy loss  11351.43
# value loss  2044.5708
# policy loss  1843.7075
# value loss  1859.8613
# policy loss  -979.2285
# value loss  2130.6885
# policy loss  -52260.695
# value loss  2083.4631
# policy loss  -14820.454
# value loss  2084.901
# policy loss  -22533.48
# value loss  1619.8218
# policy loss  -9255.319
# value loss  1779.8684
# policy loss  -60723.91
# value loss  7184.6494
# policy loss  -43694.973
# value loss  1654.6682
# policy loss  -416.35742
# value loss  2638.129
# policy loss  -9413.311
# value loss  1685.7202
# policy loss  -31340.219
# value loss  2100.9639
# policy loss  -63148.33
# value loss  6048.6963
# policy loss  -20906.021
# value loss  1857.1074
# policy loss  -37404.18
# value loss  1860.845
# policy loss  -54357.984
# value loss  4305.6357
# policy loss  -40606.91
# value loss  2867.2861
# policy loss  -6538.6787
# value loss  1559.0273
# policy loss  27402.955
# value loss  2683.6812
# policy loss  -331.07178
# value loss  1477.7537
# policy loss  24004.094
# value loss  2378.0044
# policy loss  4430.8594
# value loss  1873.3368
# policy loss  9188.689
# value loss  1816.9485
# policy loss  25909.914
# value loss  1869.8824
# policy loss  7105.749
# value loss  2101.6028
# policy loss  28564.553
# value loss  2939.7314
# policy loss  26266.273
# value loss  2288.2896
# policy loss  19020.8
# value loss  2962.7378
# policy loss  30035.7
# value loss  1942.55
# policy loss  -2438.8643
# value loss  1935.7507
# policy loss  -28124.68
# value loss  2438.005
# policy loss  36363.867
# value loss  3008.038
# policy loss  -2196.997
# value loss  1811.9073
# policy loss  21094.416
# value loss  2000.8181
# policy loss  20699.59
# value loss  1952.9438
# policy loss  1990.436
# value loss  1735.363
# policy loss  40859.64
# value loss  2974.954
# policy loss  12465.796
# value loss  1675.2318
# policy loss  49914.426
# value loss  3386.7134
# policy loss  50338.04
# value loss  2707.7678
# policy loss  36443.555
# value loss  2574.1704
# policy loss  59370.566
# value loss  3707.1052
# policy loss  33843.63
# value loss  2434.457
# policy loss  35202.867
# value loss  2576.2544
# policy loss  -47172.85
# value loss  6336.165
# policy loss  59304.92
# value loss  2938.3696
# policy loss  -14392.233
# value loss  2018.8569
# policy loss  17410.412
# value loss  1707.198
# policy loss  -50808.2
# value loss  3585.879
# policy loss  37018.957
# value loss  2120.39
# policy loss  34605.652
# value loss  1944.0933
# policy loss  31202.979
# value loss  1848.907
# policy loss  7043.368
# value loss  1254.5774
# policy loss  9145.41
# value loss  2048.8467
# policy loss  8835.176
# value loss  1521.5886
# policy loss  -2742.267
# value loss  1460.2488
# policy loss  -52370.812
# value loss  2792.2654
# policy loss  -60778.305
# value loss  5573.6807
# policy loss  22088.824
# value loss  2035.4973
# policy loss  -16239.72
# value loss  1293.015
# policy loss  -7804.1606
# value loss  1805.1873
# policy loss  -1046.4102
# value loss  1766.466
# policy loss  20711.43
# value loss  2636.0195
# policy loss  -3783.4563
# value loss  2020.8776
# policy loss  -24905.508
# value loss  2253.5063
# policy loss  -31244.746
# value loss  2093.4082
# policy loss  -7394.4395
# value loss  2364.9224
# policy loss  -11405.041
# value loss  2553.9666
# policy loss  -6549.866
# value loss  2192.099
# policy loss  4207.548
# value loss  1614.9144
# policy loss  135.9458
# value loss  2138.6123
# policy loss  -16873.24
# value loss  1846.4634
# policy loss  -28167.39
# value loss  2271.5774
# policy loss  46461.363
# value loss  2889.2432
# policy loss  -8367.178
# value loss  2578.498
# policy loss  15511.906
# value loss  1861.0522
# policy loss  6938.9355
# value loss  1399.4509
# policy loss  36614.508
# value loss  2307.0828
# policy loss  35804.0
# value loss  1767.9884
# policy loss  -10317.236
# value loss  6453.0854
# policy loss  -12389.761
# value loss  6494.001
# policy loss  -11872.004
# value loss  6387.313
# policy loss  -34542.97
# value loss  1628.2808
# policy loss  -43230.836
# value loss  3136.0405
# policy loss  15538.973
# value loss  1238.1096
# policy loss  40464.35
# value loss  2299.1064
# policy loss  5313.1685
# value loss  1297.8636
# policy loss  31417.412
# value loss  1736.028
# policy loss  22525.152
# value loss  2209.635
# policy loss  29411.504
# value loss  1635.9905
# policy loss  -1809.8135
# value loss  1476.0499
# policy loss  -13016.425
# value loss  1613.2327
# policy loss  -4939.502
# value loss  911.77057
# policy loss  -25195.193
# value loss  1560.2009
# policy loss  -10484.551
# value loss  2261.2424
# policy loss  -19825.49
# value loss  2253.981
# policy loss  29885.75
# value loss  2074.8938
# policy loss  1281.6294
# value loss  2105.8618
# policy loss  -2523.6396
# value loss  1277.2812
# policy loss  28322.494
# value loss  2168.77
# policy loss  6524.8174
# value loss  2483.687
# policy loss  49180.96
# value loss  2745.9492
# policy loss  32199.94
# value loss  1929.9602
# policy loss  50023.844
# value loss  3130.6182
# policy loss  22624.98
# value loss  1244.044
# policy loss  28534.15
# value loss  2059.921
# policy loss  20632.885
# value loss  1402.186
# policy loss  33272.25
# value loss  1857.0981
# policy loss  20678.438
# value loss  651.44604
# policy loss  4737.712
# value loss  1448.4282
# policy loss  18469.639
# value loss  1942.0353
# policy loss  -46692.93
# value loss  3484.1501
# policy loss  -50076.344
# value loss  4898.481
# policy loss  -46190.883
# value loss  6106.469
# policy loss  28351.52
# value loss  2397.2595
# policy loss  -43236.58
# value loss  3075.0737
# policy loss  36791.25
# value loss  2050.6904
# policy loss  46363.29
# value loss  2435.5989
# policy loss  3012.8853
# value loss  2137.204
# policy loss  25838.582
# value loss  1775.4985
